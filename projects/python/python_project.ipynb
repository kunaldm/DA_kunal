# %% [markdown]
#                                                                CARS DATASET

# %% [markdown]
#                   In this notebook we will import the data set for different car along with their specification.
#           we will analyze the data given for the different car specifications in the data set using Pandas Data Frame

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
car = pd.read_csv('cars.csv')

# %%
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# 1.) Find for the null values in any couloumn of the given dataset.

# %%
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         0
# Wheelbase      4
# Length         4
# dtype: int64

# %%
car['Cylinders'].fillna(car['Cylinders'].mean())
# Out:
# 0      6.0
# 1      4.0
# 2      4.0
# 3      6.0
# 4      6.0
#       ...
# 427    5.0
# 428    5.0
# 429    6.0
# 430    4.0
# 431    5.0
# Name: Cylinders, Length: 432, dtype: float64

# %%
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         0
# Wheelbase      4
# Length         4
# dtype: int64

# %%
car['Length'].fillna(car['Length'].mean(), inplace = True)
# Out:
# C:\Users\Kunal Singh\AppData\Local\Temp\ipykernel_17776\3747745131.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['Length'].fillna(car['Length'].mean(), inplace = True)

# %%
mean_val = car['Weight'].mean()

# %%
#here we fill the null values in Length coloumn with the mean of that coloumn
car.fillna({'Length' : car['Length'].mean()}, inplace = True)

# %%
#we check if the null values for length coloumn have been removed or not
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      0
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         0
# Wheelbase      4
# Length         0
# dtype: int64

# %% [markdown]
# 2.) Find the different type of cars make(produced) and their count with them

# %%
car['Make'].value_counts()
# Out:
# Make
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: count, dtype: int64

# %% [markdown]
# 3.) Show the details for the car having their origin first in Asia then Europe and finally both combined

# %%
car[car['Origin'] == 'Asia']
# Out:
#        Make                       Model    Type Origin DriveTrain      MSRP  \
# 0     Acura                         MDX     SUV   Asia        All  $36,945
# 1     Acura              RSX Type S 2dr   Sedan   Asia      Front  $23,820
# 2     Acura                     TSX 4dr   Sedan   Asia      Front  $26,990
# 3     Acura                      TL 4dr   Sedan   Asia      Front  $33,195
# 4     Acura                  3.5 RL 4dr   Sedan   Asia      Front  $43,755
# ..      ...                         ...     ...    ...        ...       ...
# 400  Toyota  MR2 Spyder convertible 2dr  Sports   Asia       Rear  $25,130
# 401  Toyota                      Tacoma   Truck   Asia       Rear  $12,800
# 402  Toyota       Tundra Regular Cab V6   Truck   Asia       Rear  $16,495
# 403  Toyota    Tundra Access Cab V6 SR5   Truck   Asia        All  $25,935
# 404  Toyota                   Matrix XR   Wagon   Asia      Front  $16,695
#
# ...

# %%
car[car['Origin'] == 'Europe']
# Out:
#       Make                      Model   Type  Origin DriveTrain      MSRP  \
# 7     Audi                A4 1.8T 4dr  Sedan  Europe      Front  $25,940
# 8     Audi     A41.8T convertible 2dr  Sedan  Europe      Front  $35,940
# 9     Audi                 A4 3.0 4dr  Sedan  Europe      Front  $31,840
# 10    Audi  A4 3.0 Quattro 4dr manual  Sedan  Europe        All  $33,430
# 11    Audi    A4 3.0 Quattro 4dr auto  Sedan  Europe        All  $34,480
# ..     ...                        ...    ...     ...        ...       ...
# 427  Volvo    C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo    C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo                 S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                        V40  Wagon  Europe      Front  $26,135
# 431  Volvo                       XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
car[car['Origin'].isin(['Asia', 'Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# 4.) Finding/Identifying the cars having their weight greater than 5000 and then print the list of all the cars not having their weight above than 5000 category.

# %%
car[car['Weight'] > 5000]
# Out:
#               Make                  Model   Type  Origin DriveTrain      MSRP  \
# 57        Cadillac               Escalade    SUV     USA      Front  $52,795
# 64        Cadillac           Escalade EXT  Truck     USA        All  $52,975
# 66       Chevrolet               Tahoe LT    SUV     USA        All  $41,465
# 86       Chevrolet         Avalanche 1500  Truck     USA        All  $36,100
# 120           Ford      Excursion 6.8 XLT    SUV     USA        All  $41,475
# 139           Ford  F-150 Supercab Lariat  Truck     USA        All  $33,540
# 144            GMC         Yukon 1500 SLE    SUV     USA      Front  $35,725
# 145            GMC      Yukon XL 2500 SLT    SUV     USA        All  $46,265
# 149            GMC         Sierra HD 2500  Truck     USA        All  $29,322
# 169         Hummer                     H2    SUV     USA        All  $49,995
# 219     Land Rover        Range Rover HSE    SUV  Europe        All  $72,250
# ...

# %%
car[~(car['Weight'] > 5000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# 5.) Identify the detail for the maximum invoice of the car having weight more than 5000 and then giving a 30% discount in the invoice for that car

# %%
#we ideantify the max value of invoice of the car having the weight category above 5000
car[car['Weight'] > 5000].max()['Invoice']
# Out:
# '$71,540 '

# %%
y = car[car['Weight'] > 5000].max()['Invoice']
y
# Out:
# '$71,540 '

# %%
car[car['Invoice'] == '$71,540 ']
# Out:
#               Make Model Type  Origin DriveTrain      MSRP   Invoice  \
# 255  Mercedes-Benz  G500  SUV  Europe        All  $76,870   $71,540
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 255         5.0        8.0       292.0      13.0         14.0  5423.0
#
#      Wheelbase  Length
# 255      112.0   186.0

# %%
#here we give a 30% discount on that invoice which we find above.
x = 0.3 * 71540
71540 - x
# Out:
# 50078.0

# %%
#we upadate the invoice value with the new discounted value.
car['Invoice'].replace('$71,540 ', '$50078', inplace= True)
# Out:
# C:\Users\Kunal Singh\AppData\Local\Temp\ipykernel_20612\3317339800.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car['Invoice'].replace('$71,540 ', '$50078', inplace= True)

# %%
#verifying the changes that we made above
car.loc[255]
# Out:
# Make           Mercedes-Benz
# Model                   G500
# Type                     SUV
# Origin                Europe
# DriveTrain               All
# MSRP                $76,870
# Invoice               $50078
# EngineSize               5.0
# Cylinders                8.0
# Horsepower             292.0
# MPG_City                13.0
# MPG_Highway             14.0
# Weight                5423.0
# Wheelbase              112.0
# Length                 186.0
# Name: 255, dtype: object

# %% [markdown]
# 6. Finding out the Suv type category from the given data and then reduce the length of all the Suv by 5 units

# %%
kar = car[car['Type'] == 'SUV']
kar
# Out:
#               Make                            Model Type  Origin DriveTrain  \
# 0            Acura                              MDX  SUV    Asia        All
# 26             BMW                          X3 3.0i  SUV  Europe        All
# 27             BMW                          X5 4.4i  SUV  Europe        All
# 48           Buick                          Rainier  SUV     USA        All
# 49           Buick                    Rendezvous CX  SUV     USA      Front
# 57        Cadillac                         Escalade  SUV     USA      Front
# 58        Cadillac                           SRX V8  SUV     USA      Front
# 65       Chevrolet                 Suburban 1500 LT  SUV     USA      Front
# 66       Chevrolet                         Tahoe LT  SUV     USA        All
# 67       Chevrolet                   TrailBlazer LT  SUV     USA      Front
# 68       Chevrolet                          Tracker  SUV     USA      Front
# ...

# %%
catg_suv_length = kar['Length'].apply(lambda x:x-5)

# %%
catg_suv_length
# Out:
# 0      184.0
# 26     175.0
# 27     179.0
# 48     188.0
# 49     182.0
# 57     194.0
# 58     190.0
# 65     214.0
# 66     192.0
# 67     187.0
# 68     158.0
# 107    196.0
# 120    222.0
# 121    201.0
# 122    185.0
# 123    168.0
# 143    203.0
# 144    194.0
# 145    214.0
# 153    183.0
# 154    174.0
# 155    162.0
# 169    185.0
# 170    172.0
# 191    203.0
# 192    173.0
# 205    176.0
# 206    169.0
# 207    145.0
# 208    175.0
# 219    190.0
# 220    180.0
# 221    170.0
# 222    183.0
# 223    188.0
# 224    181.0
# 233    201.0
# 234    188.0
# 244    168.0
# 255    181.0
# 256    178.0
# 281    185.0
# 290    185.0
# 291    185.0
# 292    174.0
# 303    202.0
# 304    178.0
# 305    173.0
# 323    177.0
# 334    183.0
# 348    176.0
# 369    182.0
# 370    158.0
# 378    199.0
# 379    184.0
# 380    180.0
# 381    188.0
# 382    162.0
# 405    182.0
# 420    184.0
# Name: Length, dtype: float64

# %% [markdown]
# 7. Identifying the highest manufacturing continents and then which type that continent produce the most and what is that number?

# %%
#dividing our search based on the origin of the cars
sns.countplot( x = 'Origin', data = car)
# Out:
# <Axes: xlabel='Origin', ylabel='count'>

# %%
#from above observation we find the asia to be predominant than the other in terms of car manufacturing
car_asia = car[car['Origin'] == 'Asia']

# %%
#associating the number figure i.e count with the observations
car_sedan.count()
# Out:
# Make           94
# Model          94
# Type           94
# Origin         94
# DriveTrain     94
# MSRP           94
# Invoice        94
# EngineSize     94
# Cylinders      94
# Horsepower     94
# MPG_City       94
# MPG_Highway    94
# Weight         94
# Wheelbase      94
# Length         94
# dtype: int64

# %%
#now dviding the search to how many and which type of the car is being made predominantly in the asia
sns.countplot( x = 'Type', data = car_asia)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
#we find the sedan to being manufactured at par more than any other type in asia
car_sedan = car_asia[car_asia['Type']=='Sedan']
#associating the number figure i.e count with the observations
car_sedan.count()
# Out:
# Make           94
# Model          94
# Type           94
# Origin         94
# DriveTrain     94
# MSRP           94
# Invoice        94
# EngineSize     94
# Cylinders      94
# Horsepower     94
# MPG_City       94
# MPG_Highway    94
# Weight         94
# Wheelbase      94
# Length         94
# dtype: int64

# %% [markdown]
# 8. Find the revenue generated in the each origin and identifying which origin is generating more revenue as compare to others

# %%
car['Invoice'] = car['Invoice'].str.replace('$','')
car['Invoice'] = car['Invoice'].str.replace(',','')

# %%
car['Invoice'] = car['Invoice'].astype(float)

# %%
sns.jointplot(x='Origin', y='Invoice', data= car)
#here we find origin, Europe is generating much revenue as compared to other two

# %%
sns.pairplot(car)

# %% [markdown]
# 9. Identifying at which horsepower range the purchase is being made more frequent for.

# %%
sns.jointplot(x='Invoice', y='Horsepower', data = car, kind = 'hex')
